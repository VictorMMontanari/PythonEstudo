# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorMMontanari/PythonEstudo/blob/main/ExercicoArvoreBinaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Implementando a estrutura de dados Árvore em Python 
# Criando uma classe para o objeto Node
class Node(object):
  #Inicializando o nó
  def __init__(self, data):
    self.leftChild = None
    self.rightChild = None 
    self.data = data

# %%
node1 = Node(50)
node2 = Node(20)
node3 = Node(45)
node4 = Node(11)
node5 = Node(15)
node6 = Node(30)
node7 = Node(78)

# %%
node1.leftChild = node2
node1.rightChild = node3
node2.leftChild = node4
node2.rightChild = node5
node3.leftChild = node6
node3.rightChild = node7

# %%
print("Nó 1 é:")
print (node1.data)
print("Filho à esquerda:")
print (node1.leftChild.data)
print("Filho à direita:")
print (node1. rightChild.data)
print("Nó 2 é::")
print (node2.data)

# %%
class Node(object):
  def __init__(self, data):
    self.leftChild = None
    self.rightChild = None 
    self.data = data

node1 = Node(99)
node2 = Node(87)
node3 = Node(89)
node4 = Node(77)
node5 = Node(79)
node6 = Node(81)
node7 = Node(84)
node8 = Node(53)
node9 = Node(58)
node10 = Node(64)
node11 = Node(61)

node1.leftChild= node2
node1.rightChild= node3
node2.leftChild= node4
node2.rightChild= node5
node3.leftChild= node6
node3.rightChild= node7
node4.leftChild= node8
node4.rightChild= node9
node5.leftChild= None
node5.rightChild= None
node6.leftChild= None
node6.rightChild= None
node7.leftChild= node10
node7.rightChild= node11
node8.leftChild= None
node8.rightChild= None
node9.leftChild= None
node9.rightChild= None
node10.leftChild= None
node10.rightChild= None
node11.leftChild= None
node11.rightChild= None

print("Nó 1 é:")
print (node1.data)
print("Filho à esquerda:")
print (node1.leftChild.data)
print("Filho à direita:")
print (node1. rightChild.data)

print("Nó 2 é::")
print (node2.data)
print("Filho à esquerda:")
print (node2.leftChild.data)
print("Filho à direita:")
print (node2. rightChild.data)

print("Nó 3 é::")
print (node3.data)
print("Filho à esquerda:")
print (node3.leftChild.data)
print("Filho à direita:")
print (node3. rightChild.data)

print("Nó 4 é::")
print (node4.data)
print("Filho à esquerda:")
print (node4.leftChild.data)
print("Filho à direita:")
print (node4. rightChild.data)

print("Nó 5 é::")
print (node5.data)
print("Filho à esquerda:")
print (node5.leftChild)
print("Filho à direita:")
print (node5. rightChild)

print("Nó 6 é::")
print (node6.data)
print("Filho à esquerda:")
print (node6.leftChild)
print("Filho à direita:")
print (node6. rightChild)

print("Nó 7 é::")
print (node7.data)
print("Filho à esquerda:")
print (node7.leftChild.data)
print("Filho à direita:")
print (node7. rightChild.data)

print("Nó 8 é::")
print (node8.data)
print("Filho à esquerda:")
print (node8.leftChild)
print("Filho à direita:")
print (node8. rightChild)

print("Nó 9 é::")
print (node9.data)
print("Filho à esquerda:")
print (node9.leftChild)
print("Filho à direita:")
print (node9. rightChild)

print("Nó 10 é::")
print (node10.data)
print("Filho à esquerda:")
print (node10.leftChild)
print("Filho à direita:")
print (node10. rightChild)

print("Nó 11 é::")
print (node11.data)
print("Filho à esquerda:")
print (node11.leftChild)
print("Filho à direita:")
print (node11. rightChild)
# Out:
# Nó 1 é:
# 99
# Filho à esquerda:
# 87
# Filho à direita:
# 89
# Nó 2 é::
# 87
# Filho à esquerda:
# 77
# Filho à direita:
# 79
# Nó 3 é::
# 89
# Filho à esquerda:
# 81
# Filho à direita:
# 84
# Nó 4 é::
# 77
# Filho à esquerda:
# 53
# Filho à direita:
# 58
# Nó 5 é::
# 79
# Filho à esquerda:
# None
# Filho à direita:
# None
# Nó 6 é::
# 81
# Filho à esquerda:
# None
# Filho à direita:
# None
# Nó 7 é::
# 84
# Filho à esquerda:
# 64
# Filho à direita:
# 61
# Nó 8 é::
# 53
# Filho à esquerda:
# None
# Filho à direita:
# None
# Nó 9 é::
# 58
# Filho à esquerda:
# None
# Filho à direita:
# None
# Nó 10 é::
# 64
# Filho à esquerda:
# None
# Filho à direita:
# None
# Nó 11 é::
# 61
# Filho à esquerda:
# None
# Filho à direita:
# None
